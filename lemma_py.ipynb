# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/lemma_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Download wordnet data (run once)
nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# List of words to lemmatize
words = ["cats", "running", "better", "feet", "cars"]

# Lemmatize each word (default pos is noun)
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

print("Original words:", words)
print("Lemmatized words:", lemmatized_words)
# Out:
# Original words: ['cats', 'running', 'better', 'feet', 'cars']
# Lemmatized words: ['cat', 'running', 'better', 'foot', 'car']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
