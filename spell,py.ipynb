# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/spell%2Cpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pyspellchecker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 45.9 MB/s eta 0:00:00
# ...

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
text = "Ths is a smple sentnce with erors"
corrected = " ".join([spell.correction(w) for w in text.split()])

print("Original:", text)
print("Corrected:", corrected)
# Out:
# Original: Ths is a smple sentnce with erors
# Corrected: the is a simple sentence with errors
