# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/ngram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

text = "I love NLP and I love Python".split()
vocab = set(text)
V = len(vocab)
bigrams = [(text[i], text[i+1]) for i in range(len(text)-1)]
bigram_counts = Counter(bigrams)
unigram_counts = Counter(text)

def prob(w1, w2):
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + V)

print("P(love|I) =", prob("I", "love"))
# Out:
# P(love|I) = 0.42857142857142855
