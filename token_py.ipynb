# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/token_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple tokenization by splitting text on spaces

text = "Hello! Welcome to NLP tokenization."

tokens = text.split()

print("Original text:", text)
print("Tokens:", tokens)
# Out:
# Original text: Hello! Welcome to NLP tokenization.
# Tokens: ['Hello!', 'Welcome', 'to', 'NLP', 'tokenization.']
