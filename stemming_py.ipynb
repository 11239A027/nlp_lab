# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/stemming_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer

# Download punkt if needed (for tokenization, optional here)
nltk.download('punkt')

# Initialize the stemmer
stemmer = PorterStemmer()

# List of words to stem
words = ["running", "runs", "runner", "easily", "fairly"]

# Stem each word
stemmed_words = [stemmer.stem(word) for word in words]

print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Original words: ['running', 'runs', 'runner', 'easily', 'fairly']
# Stemmed words: ['run', 'run', 'runner', 'easili', 'fairli']
