# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A027/nlp_lab/blob/main/unigram_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter


text = "I love NLP and I love Python"


words = text.split()


counts = Counter(words)


total = sum(counts.values())
unigram_model = {w: c / total for w, c in counts.items()}

print(unigram_model)
# Out:
# {'I': 0.2857142857142857, 'love': 0.2857142857142857, 'NLP': 0.14285714285714285, 'and': 0.14285714285714285, 'Python': 0.14285714285714285}
